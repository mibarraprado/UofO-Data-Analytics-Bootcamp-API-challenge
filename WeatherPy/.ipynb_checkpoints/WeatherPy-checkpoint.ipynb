# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
#print(cities)
# Out:
# Number of cities in the list: 615

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&units="+ units+ "&q=" + city
  
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
    
    # Convert the API response to JSON format

        city_weather_response = requests.get(city_url)
        city_weather = city_weather_response.json()
       
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country =city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | sao joao da barra
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | kahului
# Processing Record 9 of Set 1 | coahuayana
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | talnakh
# Processing Record 12 of Set 1 | jaru
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | vanimo
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | muros
# Processing Record 19 of Set 1 | ponta do sol
# Processing Record 20 of Set 1 | enshi
# Processing Record 21 of Set 1 | butaritari
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             albany  42.6001  -73.9662      4.08        84         100
# 1       puerto ayora  -0.7393  -90.3518     24.75        95          98
# 2  sao joao da barra -21.6403  -41.0511     24.25        89          99
# 3        yellowknife  62.4560 -114.3525    -30.25        69           0
# 4         nikolskoye  59.7035   30.7861      0.94        97         100
#
#    Wind Speed Country        Date
# 0        2.68      US  1675059978
# 1        0.65      EC  1675060247
# 2        7.44      BR  1675060248
# 3        4.63      CA  1675060248
# 4        6.00      RU  1675060248

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   albany  42.6001  -73.9662      4.08        84         100
# 1             puerto ayora  -0.7393  -90.3518     24.75        95          98
# 2        sao joao da barra -21.6403  -41.0511     24.25        89          99
# 3              yellowknife  62.4560 -114.3525    -30.25        69           0
# 4               nikolskoye  59.7035   30.7861      0.94        97         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.68      US  1675059978
# 1              0.65      EC  1675060247
# 2              7.44      BR  1675060248
# 3              4.63      CA  1675060248
# 4              6.00      RU  1675060248

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

plt.scatter(np.array(city_data_df["Lat"]), np.array(city_data_df["Max Temp"]), marker="o")
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Max Temperature vs. Latitude")
plt.ylabel(" Max Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
plt.scatter(np.array(city_data_df["Lat"]), np.array(city_data_df["Humidity"]), marker="o")
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Humidity vs. Latitude")
plt.ylabel(" Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(np.array(city_data_df["Lat"]), np.array(city_data_df["Cloudiness"]), marker="o")
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Cloudiness vs. Latitude")
plt.ylabel(" Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(np.array(city_data_df["Lat"]), np.array(city_data_df["Wind Speed"]), marker="o")
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Wind Speed vs. Latitude")
plt.ylabel(" Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"]>=0),:]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             albany  42.6001  -73.9662      4.08        84         100
# 3        yellowknife  62.4560 -114.3525    -30.25        69           0
# 4         nikolskoye  59.7035   30.7861      0.94        97         100
# 5         chokurdakh  70.6333  147.9167    -28.04        97         100
# 7            kahului  20.8947 -156.4700     23.25        83         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.68      US  1675059978
# 3              4.63      CA  1675060248
# 4              6.00      RU  1675060248
# 5              4.01      RU  1675060249
# 7              6.17      US  1675060249

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"]<0),:]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             puerto ayora  -0.7393  -90.3518     24.75        95          98
# 2        sao joao da barra -21.6403  -41.0511     24.25        89          99
# 6                   avarua -21.2078 -159.7750     25.03        88         100
# 11                    jaru -10.4389  -62.4664     21.41        99          94
# 12                   bluff -46.6000  168.3333     16.02        85         100
#
#          Wind Speed Country        Date
# City_ID
# 1              0.65      EC  1675060247
# 2              7.44      BR  1675060248
# 6              4.12      CK  1675060249
# 11             1.14      BR  1675060076
# 12             4.04      NZ  1675060251

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = np.array(northern_hemi_df['Lat'])
y_values = np.array(northern_hemi_df['Max Temp'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#Line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.annotate(line_eq,(2,-30),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7170757236141708

# %%
# Linear regression on Southern Hemisphere
x_values = np.array(southern_hemi_df['Lat'])
y_values = np.array(southern_hemi_df['Max Temp'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#Line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.1793435424473893

# %% [markdown]
# **Discussion about the linear relationship: there is a linaer relationship between max temperature and latitud. Warmer places tend to be nearthe equator (Lat 0)

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = np.array(northern_hemi_df['Lat'])
y_values = np.array(northern_hemi_df['Humidity'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#Line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(50,20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.1497913903499812

# %%
# Southern Hemisphere
x_values = np.array(southern_hemi_df['Lat'])
y_values = np.array(southern_hemi_df['Humidity'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#Line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(-20,20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.11104532595348747

# %% [markdown]
# **Discussion about the linear relationship:there is a linear relationship between humidity and latitud. Mor humid places tend to be near the equator (Lat 0)

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = np.array(northern_hemi_df['Lat'])
y_values = np.array(northern_hemi_df['Cloudiness'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#Line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(40,50),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.09217337879039927

# %%
# Southern Hemisphere
x_values = np.array(southern_hemi_df['Lat'])
y_values = np.array(southern_hemi_df['Cloudiness'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#Line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(-55,30),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.04126843675910953

# %% [markdown]
# **Discussion about the linear relationship:No clearly observed relationship between cloudiness and Latitude

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = np.array(northern_hemi_df['Wind Speed'])
y_values = np.array(northern_hemi_df['Cloudiness'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#Line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Wind Speed')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(12,60),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.01199168538465639

# %%
# Southern Hemisphere
x_values = np.array(southern_hemi_df['Wind Speed'])
y_values = np.array(southern_hemi_df['Cloudiness'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#Line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Wind Speed')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(6,60),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.06204288090388024

# %% [markdown]
# **Discussion about the linear relationship:No clearly observed relationship between cloudiness and windspeed
